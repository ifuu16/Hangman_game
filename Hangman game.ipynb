# %%
import random

def choose_word():
    word_list = ["men", "boy", "girl", "banana", "apple"]
    return random.choice(word_list)

# %%
def display_word(word, guessed_letters):
    
    displayed = " "
    for letter in word:
        if letter in guessed_letters:
            displayed += letter + "_"
        
        else:
            display_word += "_"
    return displayed.strip()

# %%
def display_hangman(attempts):
    hangman =[
        "----",
        "|   |" ,
        "|    " +  ("O" if attempts < 6 else " "),
        "|    " + ("/|\\" if attempts < 5 else " "),
        "|    " +("/   \\" if attempts < 4 else ""),
       "_|_"
 ]
    for line in hangman:
        print(line)

# %%
 
def play_hangman():
    attempts = 6
    guessed_letters = []
    word = choose_word()
    #displayed = display_word(word, guessed_letters)
    
    while attempts > 0:
        print("You have", attempts, "attempts left")
        display_hangman(attempts)
        print("the word is:", word)
        
        guess = input("guess the word by entering a letter").lower()
        
        if len(guess) == 1 and guess.isalpha():
            
            
            
            if guess not in guessed_letters:
                guessed_letters.append(guess)

            else:
                print("Please the input should be a single letter and an alphabet")




            if guess in word:
                print("excellent!")

            else:
                print("Try again!")
                attempts -= 1

            if all(letter in guessed_letters for letter in word):
                print("You did it!")
                break
                
        else:
            print("letter already guessed")
            continue
            
    if attempts == 0:
        print("You've been hanged, you can play again. The word is", word)
            
            
            
play_hangman()
# Out:
# You have 6 attempts left
# ----
# |   |
# |
# |
# |
# _|_
# the word is: men
# guess the word by entering a letteru
# Try again!
# You have 5 attempts left
# ----
# |   |
# |    O
# |
# |
# _|_
# the word is: men
# guess the word by entering a letterj
# Try again!
# You have 4 attempts left
# ----
# |   |
# |    O
# |    /|\
# |
# _|_
# the word is: men
# guess the word by entering a lettert
# Try again!
# You have 3 attempts left
# ----
# |   |
# |    O
# |    /|\
# |    /   \
# _|_
# the word is: men
# guess the word by entering a letterm
# excellent!
# You have 3 attempts left
# ----
# |   |
# |    O
# |    /|\
# |    /   \
# _|_
# the word is: men
# guess the word by entering a letterk
# Try again!
# You have 2 attempts left
# ----
# |   |
# |    O
# |    /|\
# |    /   \
# _|_
# the word is: men
# guess the word by entering a lettert
# Please the input should be a single letter and an alphabet
# Try again!
# You have 1 attempts left
# ----
# |   |
# |    O
# |    /|\
# |    /   \
# _|_
# the word is: men
# guess the word by entering a lettert
# Please the input should be a single letter and an alphabet
# Try again!
# You've been hanged, you can play again. The word is men
